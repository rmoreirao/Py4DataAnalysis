# %%
import pandas as pd

# %%
 names1880 = pd.read_csv('..\\Resources\\pydata-book-master\\ch02\\names\\yob1880.txt', names=['name', 'sex', 'births'])

# %%
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     794
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# 1971    Phineas   M       5
# 1972    Presley   M       5
# 1973     Ransom   M       5
# 1974      Reece   M       5
# 1975       Rene   M       5
# 1976    Roswell   M       5
# 1977    Rowland   M       5
# 1978    Sampson   M       5
# 1979     Samual   M       5
# 1980     Santos   M       5
# 1981   Schuyler   M       5
# 1982   Sheppard   M       5
# 1983   Spurgeon   M       5
# 1984   Starling   M       5
# 1985   Sylvanus   M       5
# 1986   Theadore   M       5
# 1987  Theophile   M       5
# 1988     Tilmon   M       5
# 1989      Tommy   M       5
# 1990    Unknown   M       5
# 1991       Vann   M       5
# 1992        Wes   M       5
# 1993    Winston   M       5
# 1994       Wood   M       5
# 1995     Woodie   M       5
# 1996     Worthy   M       5
# 1997     Wright   M       5
# 1998       York   M       5
# 1999  Zachariah   M       5
#
# [2000 rows x 3 columns]

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
years = range(1880, 2011)

# %%
pieces = []
columns = ['name', 'sex', 'births']

# %%
for year in years:
    path = '..\\Resources\\pydata-book-master\\ch02\\names\\yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)
    frame['year'] = year
    pieces.append(frame)

names = pd.concat(pieces, ignore_index=True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     794  1880
# 23          Jennie   F     793  1880
# 24        Gertrude   F     787  1880
# 25           Julia   F     783  1880
# 26          Hattie   F     769  1880
# 27           Edith   F     768  1880
# 28          Mattie   F     704  1880
# 29            Rose   F     700  1880
# ...            ...  ..     ...   ...
# 3381538    Zaviyon   M       5  2010
# 3381539   Zaybrien   M       5  2010
# 3381540   Zayshawn   M       5  2010
# 3381541     Zayyan   M       5  2010
# 3381542       Zeal   M       5  2010
# 3381543     Zealan   M       5  2010
# 3381544   Zecharia   M       5  2010
# 3381545   Zeferino   M       5  2010
# 3381546   Zekariah   M       5  2010
# 3381547       Zeki   M       5  2010
# 3381548     Zeriah   M       5  2010
# 3381549     Zeshan   M       5  2010
# 3381550     Zhyier   M       5  2010
# 3381551   Zildjian   M       5  2010
# 3381552       Zinn   M       5  2010
# 3381553     Zishan   M       5  2010
# 3381554      Ziven   M       5  2010
# 3381555      Zmari   M       5  2010
# 3381556      Zoren   M       5  2010
# 3381557     Zuhaib   M       5  2010
# 3381558     Zyeire   M       5  2010
# 3381559    Zygmunt   M       5  2010
# 3381560   Zykerion   M       5  2010
# 3381561      Zylar   M       5  2010
# 3381562      Zylin   M       5  2010
# 3381563    Zymaire   M       5  2010
# 3381564     Zyonne   M       5  2010
# 3381565  Zyquarius   M       5  2010
# 3381566      Zyran   M       5  2010
# 3381567      Zzyzx   M       5  2010
#
# [3381568 rows x 4 columns]

# %%
total_births = names.pivot_table('births', index='year',columns='sex', aggfunc=sum)
total_births['diff'] = (total_births['F']) / (total_births['M'])

# %%
total_births[::10]
# Out:
# sex         F        M      diff
# year
# 1880   181986   220986  0.823518
# 1890   380754   222052  1.714706
# 1900   599746   301108  1.991797
# 1910   792832   388396  2.041298
# 1920  2396428  2128936  1.125646
# 1930  2251042  2193326  1.026314
# 1940  2286562  2317336  0.986720
# 1950  3426002  3579872  0.957018
# 1960  4044124  4265176  0.948173
# 1970  3495622  3717564  0.940299
# 1980  3318518  3564776  0.930919
# 1990  3794512  4104140  0.924557
# 2000  3627920  3923404  0.924687
# 2010  3518020  3796764  0.926584

# %%
total_births.plot(title='Total births by sex and year')

# %%
total_births
# Out:
# sex         F        M
# year
# 1880   181986   220986
# 1881   183910   201496
# 1882   215702   227374
# 1883   224644   209264
# 1884   258042   228890
# 1885   266112   215604
# 1886   289076   221570
# 1887   291966   202824
# 1888   357262   241714
# 1889   356738   221180
# 1890   380754   222052
# 1891   370972   202396
# 1892   424700   244076
# 1893   425816   224638
# 1894   445846   231550
# 1895   467264   234796
# 1896   475848   239150
# 1897   468398   225520
# 1898   517542   245406
# 1899   466044   212436
# 1900   599746   301108
# 1901   478702   212956
# 1902   528158   245320
# 1903   523952   238480
# 1904   550750   256258
# 1905   583282   264638
# 1906   590602   266318
# 1907   637116   293676
# 1908   668554   308678
# 1909   694382   327966
# ...       ...      ...
# 1981  3333666  3579136
# 1982  3384072  3625284
# 1983  3338972  3581340
# 1984  3364792  3605470
# 1985  3438900  3692324
# 1986  3428106  3678884
# 1987  3475016  3730226
# 1988  3558224  3823716
# 1989  3686114  3999680
# 1990  3794512  4104140
# 1991  3748220  4038036
# 1992  3685636  3991520
# 1993  3615590  3919424
# 1994  3568814  3860726
# 1995  3514480  3804200
# 1996  3503362  3785400
# 1997  3478662  3767142
# 1998  3530780  3819352
# 1999  3544278  3836534
# 2000  3627920  3923404
# 2001  3596568  3880996
# 2002  3588716  3877882
# 2003  3648812  3944878
# 2004  3666010  3963114
# 2005  3687780  3986570
# 2006  3792936  4100468
# 2007  3833776  4138484
# 2008  3767290  4064620
# 2009  3655286  3946718
# 2010  3518020  3796764
#
# [131 rows x 2 columns]

# %%
def add_prop(group):
 # Integer division floors
    births = group.births.astype(float)
    group['prop'] = births / births.sum()
    return group
names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.038822
# 1             Anna   F    2604  1880  0.014309
# 2             Emma   F    2003  1880  0.011006
# 3        Elizabeth   F    1939  1880  0.010655
# 4           Minnie   F    1746  1880  0.009594
# 5         Margaret   F    1578  1880  0.008671
# 6              Ida   F    1472  1880  0.008089
# 7            Alice   F    1414  1880  0.007770
# 8           Bertha   F    1320  1880  0.007253
# 9            Sarah   F    1288  1880  0.007077
# 10           Annie   F    1258  1880  0.006913
# 11           Clara   F    1226  1880  0.006737
# 12            Ella   F    1156  1880  0.006352
# 13        Florence   F    1063  1880  0.005841
# 14            Cora   F    1045  1880  0.005742
# 15          Martha   F    1040  1880  0.005715
# 16           Laura   F    1012  1880  0.005561
# 17          Nellie   F     995  1880  0.005467
# 18           Grace   F     982  1880  0.005396
# 19          Carrie   F     949  1880  0.005215
# 20           Maude   F     858  1880  0.004715
# 21           Mabel   F     808  1880  0.004440
# 22          Bessie   F     794  1880  0.004363
# 23          Jennie   F     793  1880  0.004357
# 24        Gertrude   F     787  1880  0.004325
# 25           Julia   F     783  1880  0.004303
# 26          Hattie   F     769  1880  0.004226
# 27           Edith   F     768  1880  0.004220
# 28          Mattie   F     704  1880  0.003868
# 29            Rose   F     700  1880  0.003846
# ...            ...  ..     ...   ...       ...
# 3381538    Zaviyon   M       5  2010  0.000001
# 3381539   Zaybrien   M       5  2010  0.000001
# 3381540   Zayshawn   M       5  2010  0.000001
# 3381541     Zayyan   M       5  2010  0.000001
# 3381542       Zeal   M       5  2010  0.000001
# 3381543     Zealan   M       5  2010  0.000001
# 3381544   Zecharia   M       5  2010  0.000001
# 3381545   Zeferino   M       5  2010  0.000001
# 3381546   Zekariah   M       5  2010  0.000001
# 3381547       Zeki   M       5  2010  0.000001
# 3381548     Zeriah   M       5  2010  0.000001
# 3381549     Zeshan   M       5  2010  0.000001
# 3381550     Zhyier   M       5  2010  0.000001
# 3381551   Zildjian   M       5  2010  0.000001
# 3381552       Zinn   M       5  2010  0.000001
# 3381553     Zishan   M       5  2010  0.000001
# 3381554      Ziven   M       5  2010  0.000001
# 3381555      Zmari   M       5  2010  0.000001
# 3381556      Zoren   M       5  2010  0.000001
# 3381557     Zuhaib   M       5  2010  0.000001
# 3381558     Zyeire   M       5  2010  0.000001
# 3381559    Zygmunt   M       5  2010  0.000001
# 3381560   Zykerion   M       5  2010  0.000001
# 3381561      Zylar   M       5  2010  0.000001
# 3381562      Zylin   M       5  2010  0.000001
# 3381563    Zymaire   M       5  2010  0.000001
# 3381564     Zyonne   M       5  2010  0.000001
# 3381565  Zyquarius   M       5  2010  0.000001
# 3381566      Zyran   M       5  2010  0.000001
# 3381567      Zzyzx   M       5  2010  0.000001
#
# [3381568 rows x 5 columns]

# %%
import numpy as np
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %%
def get_top1000(group):
    return group.sort_index(by='births', ascending=False)[:1000]

grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
# Out:
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)

# %%
grouped

# %%
top1000
# Out:
#                        name sex  births  year      prop
# year sex
# 1880 F   0             Mary   F    7065  1880  0.038822
#          1690784       Mary   F    7065  1880  0.038822
#          1690785       Anna   F    2604  1880  0.014309
#          1             Anna   F    2604  1880  0.014309
#          1690786       Emma   F    2003  1880  0.011006
#          2             Emma   F    2003  1880  0.011006
#          1690787  Elizabeth   F    1939  1880  0.010655
#          3        Elizabeth   F    1939  1880  0.010655
#          1690788     Minnie   F    1746  1880  0.009594
#          4           Minnie   F    1746  1880  0.009594
#          5         Margaret   F    1578  1880  0.008671
#          1690789   Margaret   F    1578  1880  0.008671
#          1690790        Ida   F    1472  1880  0.008089
#          6              Ida   F    1472  1880  0.008089
#          1690791      Alice   F    1414  1880  0.007770
#          7            Alice   F    1414  1880  0.007770
#          1690792     Bertha   F    1320  1880  0.007253
#          8           Bertha   F    1320  1880  0.007253
#          1690793      Sarah   F    1288  1880  0.007077
#          9            Sarah   F    1288  1880  0.007077
#          1690794      Annie   F    1258  1880  0.006913
#          10           Annie   F    1258  1880  0.006913
#          1690795      Clara   F    1226  1880  0.006737
#          11           Clara   F    1226  1880  0.006737
#          1690796       Ella   F    1156  1880  0.006352
#          12            Ella   F    1156  1880  0.006352
#          13        Florence   F    1063  1880  0.005841
#          1690797   Florence   F    1063  1880  0.005841
#          1690798       Cora   F    1045  1880  0.005742
#          14            Cora   F    1045  1880  0.005742
# ...                     ...  ..     ...   ...       ...
# 2010 M   1677129    Ernesto   M     529  2010  0.000139
#          3367913    Ernesto   M     529  2010  0.000139
#          3367914    Ibrahim   M     527  2010  0.000139
#          1677130    Ibrahim   M     527  2010  0.000139
#          3367915     Armani   M     526  2010  0.000139
#          3367916      Cyrus   M     526  2010  0.000139
#          3367917    Quinton   M     526  2010  0.000139
#          1677133    Quinton   M     526  2010  0.000139
#          1677132      Cyrus   M     526  2010  0.000139
#          1677131     Armani   M     526  2010  0.000139
#          3367918     Isaias   M     525  2010  0.000138
#          3367919      Reese   M     525  2010  0.000138
#          1677135      Reese   M     525  2010  0.000138
#          1677134     Isaias   M     525  2010  0.000138
#          3367920     Jaydon   M     524  2010  0.000138
#          1677136     Jaydon   M     524  2010  0.000138
#          1677137     Ryland   M     521  2010  0.000137
#          3367921     Ryland   M     521  2010  0.000137
#          1677138      Terry   M     520  2010  0.000137
#          3367922      Terry   M     520  2010  0.000137
#          3367923  Frederick   M     519  2010  0.000137
#          1677139  Frederick   M     519  2010  0.000137
#          3367924   Chandler   M     518  2010  0.000136
#          1677140   Chandler   M     518  2010  0.000136
#          3367925    Jamison   M     515  2010  0.000136
#          1677141    Jamison   M     515  2010  0.000136
#          1677142    Deandre   M     513  2010  0.000135
#          3367926    Deandre   M     513  2010  0.000135
#          1677143     Dorian   M     512  2010  0.000135
#          3367927     Dorian   M     512  2010  0.000135
#
# [262000 rows x 5 columns]

# %%
pieces = []
for year, group in names.groupby(['year', 'sex']):
    pieces.append(group.sort_index(by='births', ascending=False)[:1000])
# Out:
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
top1000 = pd.concat(pieces, ignore_index=True)

# %%
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.038822
# 1            Mary   F    7065  1880  0.038822
# 2            Anna   F    2604  1880  0.014309
# 3            Anna   F    2604  1880  0.014309
# 4            Emma   F    2003  1880  0.011006
# 5            Emma   F    2003  1880  0.011006
# 6       Elizabeth   F    1939  1880  0.010655
# 7       Elizabeth   F    1939  1880  0.010655
# 8          Minnie   F    1746  1880  0.009594
# 9          Minnie   F    1746  1880  0.009594
# 10       Margaret   F    1578  1880  0.008671
# 11       Margaret   F    1578  1880  0.008671
# 12            Ida   F    1472  1880  0.008089
# 13            Ida   F    1472  1880  0.008089
# 14          Alice   F    1414  1880  0.007770
# 15          Alice   F    1414  1880  0.007770
# 16         Bertha   F    1320  1880  0.007253
# 17         Bertha   F    1320  1880  0.007253
# 18          Sarah   F    1288  1880  0.007077
# 19          Sarah   F    1288  1880  0.007077
# 20          Annie   F    1258  1880  0.006913
# 21          Annie   F    1258  1880  0.006913
# 22          Clara   F    1226  1880  0.006737
# 23          Clara   F    1226  1880  0.006737
# 24           Ella   F    1156  1880  0.006352
# 25           Ella   F    1156  1880  0.006352
# 26       Florence   F    1063  1880  0.005841
# 27       Florence   F    1063  1880  0.005841
# 28           Cora   F    1045  1880  0.005742
# 29           Cora   F    1045  1880  0.005742
# ...           ...  ..     ...   ...       ...
# 261970    Ernesto   M     529  2010  0.000139
# 261971    Ernesto   M     529  2010  0.000139
# 261972    Ibrahim   M     527  2010  0.000139
# 261973    Ibrahim   M     527  2010  0.000139
# 261974     Armani   M     526  2010  0.000139
# 261975      Cyrus   M     526  2010  0.000139
# 261976    Quinton   M     526  2010  0.000139
# 261977    Quinton   M     526  2010  0.000139
# 261978      Cyrus   M     526  2010  0.000139
# 261979     Armani   M     526  2010  0.000139
# 261980     Isaias   M     525  2010  0.000138
# 261981      Reese   M     525  2010  0.000138
# 261982      Reese   M     525  2010  0.000138
# 261983     Isaias   M     525  2010  0.000138
# 261984     Jaydon   M     524  2010  0.000138
# 261985     Jaydon   M     524  2010  0.000138
# 261986     Ryland   M     521  2010  0.000137
# 261987     Ryland   M     521  2010  0.000137
# 261988      Terry   M     520  2010  0.000137
# 261989      Terry   M     520  2010  0.000137
# 261990  Frederick   M     519  2010  0.000137
# 261991  Frederick   M     519  2010  0.000137
# 261992   Chandler   M     518  2010  0.000136
# 261993   Chandler   M     518  2010  0.000136
# 261994    Jamison   M     515  2010  0.000136
# 261995    Jamison   M     515  2010  0.000136
# 261996    Deandre   M     513  2010  0.000135
# 261997    Deandre   M     513  2010  0.000135
# 261998     Dorian   M     512  2010  0.000135
# 261999     Dorian   M     512  2010  0.000135
#
# [262000 rows x 5 columns]

# %%
boys = top1000[top1000.sex == 'M']

# %%
girls = top1000[top1000.sex == 'F']

# %%
boys
# Out:
#              name sex  births  year      prop
# 1000         John   M    9655  1880  0.043691
# 1001         John   M    9655  1880  0.043691
# 1002      William   M    9533  1880  0.043138
# 1003      William   M    9533  1880  0.043138
# 1004        James   M    5927  1880  0.026821
# 1005        James   M    5927  1880  0.026821
# 1006      Charles   M    5348  1880  0.024201
# 1007      Charles   M    5348  1880  0.024201
# 1008       George   M    5126  1880  0.023196
# 1009       George   M    5126  1880  0.023196
# 1010        Frank   M    3242  1880  0.014671
# 1011        Frank   M    3242  1880  0.014671
# 1012       Joseph   M    2632  1880  0.011910
# 1013       Joseph   M    2632  1880  0.011910
# 1014       Thomas   M    2534  1880  0.011467
# 1015       Thomas   M    2534  1880  0.011467
# 1016        Henry   M    2444  1880  0.011060
# 1017        Henry   M    2444  1880  0.011060
# 1018       Robert   M    2416  1880  0.010933
# 1019       Robert   M    2416  1880  0.010933
# 1020       Edward   M    2364  1880  0.010698
# 1021       Edward   M    2364  1880  0.010698
# 1022        Harry   M    2152  1880  0.009738
# 1023        Harry   M    2152  1880  0.009738
# 1024       Walter   M    1755  1880  0.007942
# 1025       Walter   M    1755  1880  0.007942
# 1026       Arthur   M    1599  1880  0.007236
# 1027       Arthur   M    1599  1880  0.007236
# 1028         Fred   M    1569  1880  0.007100
# 1029         Fred   M    1569  1880  0.007100
# ...           ...  ..     ...   ...       ...
# 261970    Ernesto   M     529  2010  0.000139
# 261971    Ernesto   M     529  2010  0.000139
# 261972    Ibrahim   M     527  2010  0.000139
# 261973    Ibrahim   M     527  2010  0.000139
# 261974     Armani   M     526  2010  0.000139
# 261975      Cyrus   M     526  2010  0.000139
# 261976    Quinton   M     526  2010  0.000139
# 261977    Quinton   M     526  2010  0.000139
# 261978      Cyrus   M     526  2010  0.000139
# 261979     Armani   M     526  2010  0.000139
# 261980     Isaias   M     525  2010  0.000138
# 261981      Reese   M     525  2010  0.000138
# 261982      Reese   M     525  2010  0.000138
# 261983     Isaias   M     525  2010  0.000138
# 261984     Jaydon   M     524  2010  0.000138
# 261985     Jaydon   M     524  2010  0.000138
# 261986     Ryland   M     521  2010  0.000137
# 261987     Ryland   M     521  2010  0.000137
# 261988      Terry   M     520  2010  0.000137
# 261989      Terry   M     520  2010  0.000137
# 261990  Frederick   M     519  2010  0.000137
# 261991  Frederick   M     519  2010  0.000137
# 261992   Chandler   M     518  2010  0.000136
# 261993   Chandler   M     518  2010  0.000136
# 261994    Jamison   M     515  2010  0.000136
# 261995    Jamison   M     515  2010  0.000136
# 261996    Deandre   M     513  2010  0.000135
# 261997    Deandre   M     513  2010  0.000135
# 261998     Dorian   M     512  2010  0.000135
# 261999     Dorian   M     512  2010  0.000135
#
# [131000 rows x 5 columns]

# %%
total_births = top1000.pivot_table('births', index='year', columns='name', aggfunc=sum)

# %%
total_births
# Out:
# name   Aaden  Aaliyah    Aaron   Abbey  Abbie  Abbigail    Abby    Abe  \
# year
# 1880     NaN      NaN    204.0     NaN  142.0       NaN     NaN  100.0
# 1881     NaN      NaN    188.0     NaN  162.0       NaN     NaN   72.0
# 1882     NaN      NaN    170.0     NaN  160.0       NaN     NaN  100.0
# 1883     NaN      NaN    210.0     NaN  158.0       NaN     NaN   86.0
# 1884     NaN      NaN    194.0     NaN  196.0       NaN     NaN   90.0
# 1885     NaN      NaN    176.0     NaN  176.0       NaN     NaN   94.0
# 1886     NaN      NaN    172.0     NaN  168.0       NaN     NaN  100.0
# 1887     NaN      NaN    156.0     NaN  208.0       NaN     NaN   74.0
# 1888     NaN      NaN    180.0     NaN  274.0       NaN     NaN   92.0
# 1889     NaN      NaN    170.0     NaN  214.0       NaN     NaN   78.0
# 1890     NaN      NaN    192.0     NaN  280.0       NaN     NaN   98.0
# 1891     NaN      NaN    138.0     NaN  248.0       NaN     NaN   80.0
# 1892     NaN      NaN    190.0     NaN  238.0       NaN     NaN  106.0
# 1893     NaN      NaN    162.0     NaN  230.0       NaN     NaN   86.0
# 1894     NaN      NaN    158.0     NaN  236.0       NaN     NaN  100.0
# 1895     NaN      NaN    188.0     NaN  184.0       NaN     NaN  108.0
# 1896     NaN      NaN    138.0     NaN  242.0       NaN     NaN  102.0
# 1897     NaN      NaN    174.0     NaN  194.0       NaN     NaN  116.0
# 1898     NaN      NaN    178.0     NaN  240.0       NaN     NaN  134.0
# 1899     NaN      NaN    142.0     NaN  174.0       NaN     NaN   78.0
# 1900     NaN      NaN    208.0     NaN  224.0       NaN     NaN  112.0
# 1901     NaN      NaN    160.0     NaN  174.0       NaN     NaN   96.0
# 1902     NaN      NaN    156.0     NaN  182.0       NaN     NaN  108.0
# 1903     NaN      NaN    186.0     NaN  182.0       NaN     NaN  116.0
# 1904     NaN      NaN    234.0     NaN  160.0       NaN     NaN  104.0
# 1905     NaN      NaN    192.0     NaN  146.0       NaN     NaN  130.0
# 1906     NaN      NaN    192.0     NaN  144.0       NaN     NaN  100.0
# 1907     NaN      NaN    260.0     NaN  158.0       NaN     NaN  130.0
# 1908     NaN      NaN    228.0     NaN  168.0       NaN     NaN  114.0
# 1909     NaN      NaN    284.0     NaN  114.0       NaN     NaN  134.0
# ...      ...      ...      ...     ...    ...       ...     ...    ...
# 1981     NaN      NaN  29358.0     NaN    NaN       NaN  2422.0    NaN
# 1982     NaN      NaN  28772.0     NaN    NaN       NaN  2594.0    NaN
# 1983     NaN      NaN  28910.0   838.0    NaN       NaN  2620.0    NaN
# 1984     NaN      NaN  26774.0     NaN    NaN       NaN  2524.0    NaN
# 1985     NaN      NaN  26246.0     NaN    NaN       NaN  2414.0    NaN
# 1986     NaN      NaN  25370.0     NaN    NaN       NaN  2238.0    NaN
# 1987     NaN      NaN  25352.0     NaN    NaN       NaN  2102.0    NaN
# 1988     NaN      NaN  28786.0     NaN    NaN       NaN  2440.0    NaN
# 1989     NaN      NaN  30624.0     NaN    NaN       NaN  2552.0    NaN
# 1990     NaN      NaN  29090.0  1014.0    NaN       NaN  2586.0    NaN
# 1991     NaN      NaN  28480.0     NaN    NaN       NaN  2342.0    NaN
# 1992     NaN      NaN  28988.0     NaN    NaN       NaN  2162.0    NaN
# 1993     NaN      NaN  27638.0  1006.0    NaN       NaN  2350.0    NaN
# 1994     NaN   2902.0  28758.0  1194.0    NaN       NaN  2746.0    NaN
# 1995     NaN   2508.0  26554.0  1098.0    NaN       NaN  2756.0    NaN
# 1996     NaN   1662.0  23912.0  1104.0    NaN       NaN  2832.0    NaN
# 1997     NaN   3474.0  22312.0  1290.0    NaN       NaN  3128.0    NaN
# 1998     NaN   2798.0  21078.0  1322.0    NaN       NaN  3214.0    NaN
# 1999     NaN   2176.0  19692.0  1420.0    NaN       NaN  3618.0    NaN
# 2000     NaN   2988.0  19096.0  1320.0    NaN       NaN  3128.0    NaN
# 2001     NaN   6702.0  19058.0  1374.0    NaN       NaN  3970.0    NaN
# 2002     NaN   9550.0  17986.0  1200.0    NaN    1154.0  3922.0    NaN
# 2003     NaN   7340.0  17702.0  1250.0    NaN       NaN  4094.0    NaN
# 2004     NaN   6964.0  16762.0     NaN    NaN       NaN  4046.0    NaN
# 2005     NaN   6904.0  15592.0     NaN    NaN       NaN  3502.0    NaN
# 2006     NaN   7474.0  16558.0     NaN    NaN    1260.0  3364.0    NaN
# 2007     NaN   7882.0  17828.0     NaN    NaN    1302.0  3146.0    NaN
# 2008  1910.0   8056.0  17022.0     NaN    NaN       NaN  2656.0    NaN
# 2009  2530.0   8704.0  15872.0     NaN    NaN    1350.0  2548.0    NaN
# 2010     NaN   9256.0  14748.0     NaN    NaN       NaN  2280.0    NaN
#
# name    Abel  Abigail  ...    Zella  Zelma  Zina    Zion      Zoe     Zoey  \
# year                   ...
# 1880     NaN     12.0  ...     62.0   38.0   NaN     NaN     46.0      NaN
# 1881     NaN      NaN  ...     76.0   34.0   NaN     NaN     44.0      NaN
# 1882     NaN     14.0  ...    100.0   42.0   NaN     NaN     50.0      NaN
# 1883     NaN      NaN  ...    110.0   32.0   NaN     NaN     46.0      NaN
# 1884     NaN      NaN  ...    126.0   58.0   NaN     NaN     62.0      NaN
# 1885     NaN      NaN  ...    112.0    NaN   NaN     NaN     54.0      NaN
# 1886    32.0      NaN  ...    144.0   64.0   NaN     NaN     50.0      NaN
# 1887     NaN      NaN  ...    134.0   54.0   NaN     NaN     68.0      NaN
# 1888     NaN      NaN  ...    222.0   74.0   NaN     NaN     84.0      NaN
# 1889     NaN      NaN  ...    192.0   86.0   NaN     NaN     58.0      NaN
# 1890     NaN      NaN  ...    216.0  104.0   NaN     NaN     84.0      NaN
# 1891     NaN      NaN  ...    230.0  126.0   NaN     NaN     68.0      NaN
# 1892     NaN      NaN  ...    204.0  112.0   NaN     NaN     68.0      NaN
# 1893     NaN      NaN  ...    218.0  114.0   NaN     NaN      NaN      NaN
# 1894     NaN      NaN  ...    276.0  154.0   NaN     NaN      NaN      NaN
# 1895     NaN      NaN  ...    274.0  160.0   NaN     NaN      NaN      NaN
# 1896     NaN      NaN  ...    260.0  164.0   NaN     NaN     72.0      NaN
# 1897     NaN      NaN  ...    256.0  208.0   NaN     NaN     70.0      NaN
# 1898     NaN      NaN  ...    230.0  208.0   NaN     NaN      NaN      NaN
# 1899     NaN      NaN  ...    204.0  240.0   NaN     NaN      NaN      NaN
# 1900     NaN      NaN  ...    342.0  262.0   NaN     NaN      NaN      NaN
# 1901     NaN      NaN  ...    244.0  254.0   NaN     NaN      NaN      NaN
# 1902     NaN      NaN  ...    248.0  378.0   NaN     NaN      NaN      NaN
# 1903     NaN      NaN  ...    264.0  352.0   NaN     NaN      NaN      NaN
# 1904     NaN      NaN  ...    252.0  396.0   NaN     NaN      NaN      NaN
# 1905     NaN      NaN  ...    220.0  322.0   NaN     NaN      NaN      NaN
# 1906     NaN      NaN  ...    216.0  376.0   NaN     NaN      NaN      NaN
# 1907     NaN      NaN  ...    246.0  424.0   NaN     NaN      NaN      NaN
# 1908     NaN      NaN  ...    250.0  398.0   NaN     NaN      NaN      NaN
# 1909     NaN      NaN  ...    262.0  480.0   NaN     NaN      NaN      NaN
# ...      ...      ...  ...      ...    ...   ...     ...      ...      ...
# 1981   956.0   3622.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1982   934.0   3764.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1983   852.0   3812.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1984   850.0   3682.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1985   920.0   3692.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1986   964.0   3992.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1987   912.0   4000.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1988  1026.0   4744.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1989  1084.0   6802.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1990  1206.0   7438.0  ...      NaN    NaN   NaN     NaN      NaN      NaN
# 1991  1244.0   7594.0  ...      NaN    NaN   NaN     NaN   1444.0      NaN
# 1992  1262.0   7972.0  ...      NaN    NaN   NaN     NaN   1956.0      NaN
# 1993  1238.0  10362.0  ...      NaN    NaN   NaN     NaN   2388.0      NaN
# 1994  1166.0  14474.0  ...      NaN    NaN   NaN     NaN   2664.0      NaN
# 1995  1434.0  15638.0  ...      NaN    NaN   NaN     NaN   3452.0      NaN
# 1996  1212.0  17188.0  ...      NaN    NaN   NaN     NaN   4126.0      NaN
# 1997  1434.0  19242.0  ...      NaN    NaN   NaN     NaN   4726.0      NaN
# 1998  1336.0  22184.0  ...      NaN    NaN   NaN     NaN   5380.0      NaN
# 1999  1422.0  23352.0  ...      NaN    NaN   NaN  2138.0   6476.0   1122.0
# 2000  1526.0  26170.0  ...      NaN    NaN   NaN  2010.0   7566.0   1382.0
# 2001  1466.0  29598.0  ...      NaN    NaN   NaN  1734.0   9284.0   1644.0
# 2002  1548.0  30584.0  ...      NaN    NaN   NaN  1656.0   9766.0   2364.0
# 2003  1508.0  31824.0  ...      NaN    NaN   NaN  1752.0  10160.0   2930.0
# 2004  1582.0  30838.0  ...      NaN    NaN   NaN  2012.0  10718.0   3242.0
# 2005  1708.0  31476.0  ...      NaN    NaN   NaN  2230.0   9906.0   4532.0
# 2006  1844.0  31230.0  ...      NaN    NaN   NaN  2596.0  10290.0   5678.0
# 2007  1878.0  30894.0  ...      NaN    NaN   NaN  3094.0   9850.0   6056.0
# 2008  1726.0  30090.0  ...      NaN    NaN   NaN  3188.0   9528.0   6876.0
# 2009  1920.0  28684.0  ...      NaN    NaN   NaN  2932.0  10240.0   7962.0
# 2010  2238.0  28248.0  ...      NaN    NaN   NaN  3028.0  12400.0  10328.0
#
# name   Zola  Zona   Zora   Zula
# year
# 1880    NaN   NaN   56.0   54.0
# 1881    NaN   NaN   42.0   54.0
# 1882    NaN  34.0   64.0   42.0
# 1883    NaN   NaN   70.0   50.0
# 1884    NaN   NaN  116.0   54.0
# 1885    NaN   NaN   96.0   76.0
# 1886    NaN  20.0  104.0   86.0
# 1887   46.0  56.0   92.0   66.0
# 1888    NaN  60.0   84.0   90.0
# 1889    NaN  58.0  106.0  110.0
# 1890   64.0  27.0  120.0  130.0
# 1891   58.0   NaN  104.0   90.0
# 1892    NaN   NaN  132.0  106.0
# 1893   68.0   NaN  134.0  140.0
# 1894  102.0   NaN  132.0  128.0
# 1895  120.0  76.0  110.0  110.0
# 1896   94.0  76.0  144.0  130.0
# 1897  102.0   NaN  134.0  158.0
# 1898  124.0   NaN  130.0  166.0
# 1899   98.0   NaN  112.0  120.0
# 1900   96.0   NaN  198.0  142.0
# 1901  112.0   NaN  116.0  114.0
# 1902  116.0   NaN  116.0  132.0
# 1903  128.0  41.0  166.0  148.0
# 1904   92.0   NaN  108.0  148.0
# 1905  132.0   NaN  110.0  122.0
# 1906  118.0   NaN  128.0  116.0
# 1907  106.0   NaN  184.0  144.0
# 1908  140.0   NaN  118.0   53.0
# 1909  118.0   NaN  114.0  152.0
# ...     ...   ...    ...    ...
# 1981    NaN   NaN    NaN    NaN
# 1982    NaN   NaN    NaN    NaN
# 1983    NaN   NaN    NaN    NaN
# 1984    NaN   NaN    NaN    NaN
# 1985    NaN   NaN    NaN    NaN
# 1986    NaN   NaN    NaN    NaN
# 1987    NaN   NaN    NaN    NaN
# 1988    NaN   NaN    NaN    NaN
# 1989    NaN   NaN    NaN    NaN
# 1990    NaN   NaN    NaN    NaN
# 1991    NaN   NaN    NaN    NaN
# 1992    NaN   NaN    NaN    NaN
# 1993    NaN   NaN    NaN    NaN
# 1994    NaN   NaN    NaN    NaN
# 1995    NaN   NaN    NaN    NaN
# 1996    NaN   NaN    NaN    NaN
# 1997    NaN   NaN    NaN    NaN
# 1998    NaN   NaN    NaN    NaN
# 1999    NaN   NaN    NaN    NaN
# 2000    NaN   NaN    NaN    NaN
# 2001    NaN   NaN    NaN    NaN
# 2002    NaN   NaN    NaN    NaN
# 2003    NaN   NaN    NaN    NaN
# 2004    NaN   NaN    NaN    NaN
# 2005    NaN   NaN    NaN    NaN
# 2006    NaN   NaN    NaN    NaN
# 2007    NaN   NaN    NaN    NaN
# 2008    NaN   NaN    NaN    NaN
# 2009    NaN   NaN    NaN    NaN
# 2010    NaN   NaN    NaN    NaN
#
# [131 rows x 3118 columns]

# %%
 subset = total_births[['John', 'Harry', 'Mary', 'Marilyn']]

# %%
 subset.plot(subplots=True, figsize=(12, 10), grid=False,title="Number of births per year")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000002420F048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000026581A20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000002414C358>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000002414B8D0>],
#       dtype=object)

# %%
table = top1000.pivot_table('prop', index='year',columns='sex', aggfunc=sum)

# %%
table.plot(title='Sum of table1000.prop by year and sex', yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 10))

# %%
df = boys[boys.year == 2010]

# %%
df
# Out:
#                name sex  births  year      prop
# 261000        Jacob   M   21875  2010  0.005761
# 261001        Jacob   M   21875  2010  0.005761
# 261002        Ethan   M   17866  2010  0.004706
# 261003        Ethan   M   17866  2010  0.004706
# 261004      Michael   M   17133  2010  0.004513
# 261005      Michael   M   17133  2010  0.004513
# 261006       Jayden   M   17030  2010  0.004485
# 261007       Jayden   M   17030  2010  0.004485
# 261008      William   M   16870  2010  0.004443
# 261009      William   M   16870  2010  0.004443
# 261010    Alexander   M   16634  2010  0.004381
# 261011    Alexander   M   16634  2010  0.004381
# 261012         Noah   M   16281  2010  0.004288
# 261013         Noah   M   16281  2010  0.004288
# 261014       Daniel   M   15679  2010  0.004130
# 261015       Daniel   M   15679  2010  0.004130
# 261016        Aiden   M   15403  2010  0.004057
# 261017        Aiden   M   15403  2010  0.004057
# 261018      Anthony   M   15364  2010  0.004047
# 261019      Anthony   M   15364  2010  0.004047
# 261020       Joshua   M   15238  2010  0.004013
# 261021       Joshua   M   15238  2010  0.004013
# 261022        Mason   M   14728  2010  0.003879
# 261023        Mason   M   14728  2010  0.003879
# 261024  Christopher   M   14135  2010  0.003723
# 261025  Christopher   M   14135  2010  0.003723
# 261026       Andrew   M   14093  2010  0.003712
# 261027       Andrew   M   14093  2010  0.003712
# 261028        David   M   14042  2010  0.003698
# 261029        David   M   14042  2010  0.003698
# ...             ...  ..     ...   ...       ...
# 261970      Ernesto   M     529  2010  0.000139
# 261971      Ernesto   M     529  2010  0.000139
# 261972      Ibrahim   M     527  2010  0.000139
# 261973      Ibrahim   M     527  2010  0.000139
# 261974       Armani   M     526  2010  0.000139
# 261975        Cyrus   M     526  2010  0.000139
# 261976      Quinton   M     526  2010  0.000139
# 261977      Quinton   M     526  2010  0.000139
# 261978        Cyrus   M     526  2010  0.000139
# 261979       Armani   M     526  2010  0.000139
# 261980       Isaias   M     525  2010  0.000138
# 261981        Reese   M     525  2010  0.000138
# 261982        Reese   M     525  2010  0.000138
# 261983       Isaias   M     525  2010  0.000138
# 261984       Jaydon   M     524  2010  0.000138
# 261985       Jaydon   M     524  2010  0.000138
# 261986       Ryland   M     521  2010  0.000137
# 261987       Ryland   M     521  2010  0.000137
# 261988        Terry   M     520  2010  0.000137
# 261989        Terry   M     520  2010  0.000137
# 261990    Frederick   M     519  2010  0.000137
# 261991    Frederick   M     519  2010  0.000137
# 261992     Chandler   M     518  2010  0.000136
# 261993     Chandler   M     518  2010  0.000136
# 261994      Jamison   M     515  2010  0.000136
# 261995      Jamison   M     515  2010  0.000136
# 261996      Deandre   M     513  2010  0.000135
# 261997      Deandre   M     513  2010  0.000135
# 261998       Dorian   M     512  2010  0.000135
# 261999       Dorian   M     512  2010  0.000135
#
# [1000 rows x 5 columns]

# %%
prop_cumsum = df.sort_index(by='prop', ascending=False).prop.cumsum()
# Out:
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.

# %%
 prop_cumsum[:10]
# Out:
# 261000    0.005761
# 261001    0.011523
# 261002    0.016229
# 261003    0.020934
# 261004    0.025447
# 261005    0.029959
# 261006    0.034445
# 261007    0.038930
# 261008    0.043373
# 261009    0.047817
# Name: prop, dtype: float64

# %%
prop_cumsum.searchsorted(0.5)
# Out:
# array([233], dtype=int64)

# %%
 df = boys[boys.year == 1900]

# %%
 in1900 = df.sort_index(by='prop', ascending=False).prop.cumsum()
# Out:
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.

# %%
 in1900.searchsorted(0.5) + 1
# Out:
# array([50], dtype=int64)

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_index(by='prop', ascending=False)
    return group.prop.cumsum().searchsorted(q) + 1

# %%
diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)
# Out:
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)

# %%
diversity = diversity.unstack('sex')

# %%
diversity.head()
# Out:
# sex      F     M
# year
# 1880  [75]  [27]
# 1881  [75]  [27]
# 1882  [76]  [29]
# 1883  [77]  [29]
# 1884  [78]  [31]

# %%
diversity.plot(title="Number of popular names in top 50%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-5049dcce250a> in <module>()
# ----> 1 diversity.plot(title="Number of popular names in top 50%")
#
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     248     def generate(self):
#     249         self._args_adjust()
# --> 250         self._compute_plot_data()
#     251         self._setup_subplots()
#     252         self._make_plot()
#
# c:\localdev\github\py4dataanalysis\venv\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     363         if is_empty:
#     364             raise TypeError('Empty {0!r}: no numeric data to '
# --> 365                             'plot'.format(numeric_data.__class__.__name__))
#     366
#     367         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
